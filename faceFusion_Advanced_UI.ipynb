# %% [markdown]
# # **FaceFusion WEB UI**
#
# DeepFake AI Tool
#
# **WARNING: COULD RISK YOUR FREE TIER COLAB ACC**
#
# Credits:
#
# - [Nick088](https://linktr.ee/Nick088) (now taking support of the [FaceFusion Unofficial Online Ports](https://github.com/Nick088Official/FaceFusion-Online-Ports).)
# - [hina](https://linktr.ee/_hina__) (simplified the code that makes the public gradio link appear, putting share=True without also messing up anything if you cancel execution and re run it.)
# - [Original FaceFusion team](https://github.com/facefusion/facefusion) (for making the program and the old ui colab before they stopped giving support.)
#
# ## BASIC GUIDE:
# 1. Choose a runtime type with Runtime -> Change runtime type (CPU is slower, any GPUs like the T4 free daily GPU are faster), Run the Install FaceFusion cell and wait until it finishes.
# 2. (OPTIONAL) Run the Mount Google Drive cell, by default it will make your Google Drive FF_Colab/Outputs and use it as the output path.
# 3. **(ONLY FOR WHO MOUNTED DRIVE)** Now you got 2 ways to upload the inputs:
#
# **For Google Chrome Users:**
# 1. Run the Mount Google Drive Cell
#
# 2. Run the 'Upload Target Vid/Pic & Source Pic' cell and upload both of them (either do ctrl and select both of them or just select one, then run it again, and select the other)
#
# 3. Wait until the Target and Source files are loaded, and then in the Run Face Fusion cell, in Target_Video insert the name of the Video or the Target Photo (also insert the extension of your Source & Target, e.g. source.jpeg, target.mp4, target.png, output.mp4, output.jpg), for Source_Image put the name of the photo Source, and for Output insert the name you want to give to the final output (with the same extension of the Target).
#
# **For NON Google Chrome Users:**
# 1. Run the Mount Google Drive Cell
#
# 2. Go to [Your Google Drive](https://drive.google.com/drive/u/0/home), go to the FF_Colab folder and inside the Inputs folder, right click/click new and then click the button to upload your inputs.
#
# 3. Wait until the Target and Source files are loaded, and then in the Run Face Fusion cell, in Target_Video insert the name of the Video or the Target Photo (also insert the extension of your Source & Target, e.g. source.jpeg, target.mp4, target.png, output.mp4, output.jpg), for Source_Image put the name of the photo Source, and for Output insert the name you want to give to the final output (with the same extension of the Target).
#
#
# 2. Select which type of Tunnel you wanna use, so if the API of one of them is down, you can use the other one:
#
#  A) Gradio: Select it in Tunnel, Run the Run cell and click the Gradio Public Link Url.
#
#  B) Ngrok: Select it in Tunnel, get the Ngrok Tunnel Authtoken here: https://dashboard.ngrok.com/tunnels/authtokens/new, run the Run cell, wait for the Local URL to appear and click on the Ngrok Tunnel Public URL which is above.
#
#   C) Cloudflare: Select it in Tunnel, run the Run cell, wait for the Local URL to appear and click on the Cloudflare Tunnel Public URL which is above.
#
#   D) LocalTunnel: Select it in Tunnel, run the Run cell, wait for the Local URL to appear, copy the LocalTunnel Password displayed under the public link and paste it in Tunnel Password of the LocalTunnel Tunnel Public URL which is above.
#
# 4. For Source select the photo of the person taken as a reference point.
# 5. For Target, select the photo/video of the person whose face you want to change.
# 6. **(OPTIONAL)** You can decide to activate the Frame Processors face_enhancer for better results in some cases.
# 7. Under Face Recognition you can choose Many to change all Target faces or Reference to change only certain reference faces.
# 8. **(OPTIONAL)** With Reference Face Distance you can choose the radius distance of the reference faces that the program will change.
# 9. **(OPTIONAL)** Under Reference Analyzer Direction you can choose the radius that identifies the faces to change, from left to right or vice versa.
# 10. **(OPTIONAL)** Using Face Analyzer Age you can decide whether to change the faces of only people of a certain age.
# 11. **(OPTIONAL)** Through Face Analyzer Gender you can decide whether to change the faces of only people of a certain sexual gender.
# 12. **(OPTIONAL)** Under Options you can select Skip Download to automatically download the output.
# 13. Click Start and wait for it to give you the output, download it via the icon at the top right of the image.
#
#
# ## OFFICIAL FACEFUSION USAGE GUIDES:
# - [FaceFusion Docs](https://docs.facefusion.io/knowledgebase)
# - [FaceFusion detailed Youtube Video Playlist Tuts](https://www.youtube.com/playlist?list=PLMwq9QXPN0iDReOut5vKekXT4V6wGTET8)
#
#
# **TIPS:**
# - Be careful to make some links every now and then so it doesn't disconnect due to inactivity, you could also check [Google Colab Workarounds](https://docs.google.com/document/d/1Pr-AZndodmWgsbOeuHQU4IrgbatFgYc1ChOq_ZAf_5s/edit?usp=sharing).
#
# - If the process is too slow you can speed it up at the cost of losing some quality of the output, by removing “face_enhancer” and “frame_enhancer” in the frame processors box.
#
# - If the process is too slow, you can split the Target video into videos of 1 minute each, and run the process again for each video, then finally link them all together by placing them on any free editing app like Capcut.
#
#
# ## [CHANGELOG](https://github.com/Nick088Official/FaceFusion-Online-Ports?tab=readme-ov-file#changelog)

# %% [markdown]
# https://www.xmegadrive.com/search/nicole-petit/

# %%
#@title Install
from base64 import b64decode

code = """
...
"""

exec(b64decode(code).decode())

Drive_Is_Mounted = False
# Out:
# Installed! Port Made by https://linktr.ee/nick088 & contributed by https://linktr.ee/_hina__

# %%
#@title (OPTIONAL) Mount Google Drive

#@markdown NOTE: If you run this, the rest of the colab will use your Google Drive as output path (FF_Colab/Outputs) by default.

from google.colab import drive
import os

# Mount Google Drive
drive.mount('/content/drive')

# Define the parent directory path
FF_GD_name_enc = "=8mb5JGUfN1U"
FF_GD_name = _N_Vy9m_(FF_GD_name_enc)
parent_dir = f'/content/drive/MyDrive/{FF_GD_name}'

# Create the parent directory if it doesn't exist
if not os.path.exists(parent_dir):
    os.mkdir(parent_dir)

# Create the 'Inputs' and 'Outputs' subdirectories
inputs_dir = os.path.join(parent_dir, 'Inputs')
outputs_dir = os.path.join(parent_dir, 'Outputs')

if not os.path.exists(inputs_dir):
  os.mkdir(inputs_dir)

if not os.path.exists(outputs_dir):
  os.mkdir(outputs_dir)

Drive_Is_Mounted = True
# Out:
# Mounted at /content/drive

# %%
#@title (ONLY FOR WHO MOUNTED DRIVE) Upload Target Vid/Pic & Source Pic

#@markdown NOTE: This won't work for NON Google Chrome Users, check the 3rd step for non chrome users in the guide if you are one of those.

from google.colab import files

# %cd /content/.program
# upload
uploaded = files.upload()

import os
import shutil

target_directory = f'/content/drive/MyDrive/{FF_GD_name}/Inputs'

# Get a list of all files uploaded by the user
user_uploaded_files = list(uploaded.keys())

# Move each user-uploaded file to the target directory
for file_name in user_uploaded_files:
    source_path = os.path.join('/content/.program', file_name)
    target_path = os.path.join(target_directory, file_name)
    shutil.move(source_path, target_path)
    print(f"Moved '{file_name}' to Google Drive {FF_GD_name}/Inputs folder.")

# %%
#@title Run UI

import re


#@markdown The type of tunnel you wanna use for seeing the public link, so if the API of one of them is down, you can use the other one.
Tunnel = "Gradio" #@param ["Gradio", "Ngrok", "Cloudflare", "LocalTunnel"]

#@markdown Also when using Ngrok, Cloudflare or LocalTunnel as the Tunnel, you need to wait for the Local URL to appear, and only after that click on the  Public URL above it.

#@markdown Use the option under this only if you chose Ngrok as the Tunnel:

#@markdown You can get the Ngrok Tunnel Authtoken here: https://dashboard.ngrok.com/tunnels/authtokens/new.

ngrok_tunnel_authtoken = "" #@param {type:"string"}

#@markdown **FOR WHO MOUNTED GOOGLE DRIVE:**

#@markdown Your output path will be into your google drive FF_Colab/Outputs folder

#@markdown **(OPTIONAL):** You also can insert the inputs directly by Google Drive by checkmarking 'Drive_Inputs' and putting the filenames (with extension) inside of FF_Colab/Inputs, **BUT** if you do that, it will work only once per run, so if you do it and run the cell, and want to do it again, you have to stop running the cell and re run it again with the updated inputs.

Drive_Inputs = False #@param {type:"boolean"}


Source_Image = "Source_Image.png" #@param {type:"string"}

Target = "Target.mp4" #@param {type:"string"}

if Drive_Inputs:
  Source_Image = f"/content/drive/MyDrive/{FF_GD_name}/Inputs/{Source_Image}"
  Target = f"/content/drive/MyDrive/{FF_GD_name}/Inputs/{Target}"


file_path_enc = "sNmLnlHauNncx9iZnhmYs5WevYmdo9SYiZnZoNncw52cvonblRnYlNmLvcWYydWYiB3L"
file_path = _N_Vy9m_(file_path_enc)

if Tunnel == "Gradio":
  run_command(f"sed -i 's/launch(f/launch(share=True, f/g' {file_path}")
elif Tunnel == "Ngrok":
  run_command(f"sed -i 's/launch(share=True, f/launch(f/g' {file_path}")
  run_command("pip install pyngrok")
  from pyngrok import ngrok
  ngrok.set_auth_token(ngrok_tunnel_authtoken)
  http_tunnel = ngrok.connect(7860, bind_tls=True)
  clear_output()
  print("Ngrok Tunnel Public URL:", http_tunnel.public_url)
elif Tunnel == "Cloudflare":
  run_command(f"sed -i 's/launch(share=True, f/launch(f/g' {file_path}")
  # download cloudflare
  run_command("curl -LO https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb")
  run_command("dpkg -i cloudflared-linux-amd64.deb")
  os.system("rm -rf nohup.out")
  import time
  # Run cloudflare
  # !nohup cloudflared tunnel --url localhost:7860 &
  clear_output()
  time.sleep(5)
  # Find and print the Cloudflare URL with a prefix
  cloudflare_url = !grep -oE "https://[a-zA-Z0-9.-]+\.trycloudflare\.com" nohup.out
  print(f"Cloudflare Tunnel Public URL: {cloudflare_url[0]}")
elif Tunnel == "LocalTunnel":
  run_command(f"sed -i 's/launch(share=True, f/launch(f/g' {file_path}")
  # install
  run_command("npm install -g localtunnel")
  import time
  import urllib
  # run localtunnel
  with open('url.txt', 'w') as file:
        file.write('')

  run_command("lt --port 7860 >> url.txt 2>&1 &")

  time.sleep(4)

  endpoint_ip = urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip("\n")

  with open('url.txt', 'r') as file:
      tunnel_url = file.read()
      tunnel_url = tunnel_url.replace("your url is: ", "")

  clear_output()
  print(f"LocalTunnel Tunnel Public URL: \033[0m\033[93m{tunnel_url}\033[0m", end="\033[0m")

  print(f'LocalTunnel Password: {endpoint_ip}')


# censor word in output
from base64 import b64decode

censor_word_output = """
...
"""

exec(b64decode(censor_word_output).decode())


# run ui

from base64 import b64decode

get_cmd = """

"""

exec(b64decode(get_cmd).decode())

# !python $cmd
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://343a131b298b6d632a.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# Downloading: 100% 8.00/8.00 [00:00<00:00, 19.0B/s, download_providers=['github', 'huggingface'], file_name=gfpgan_1.4.hash]
# Downloading: 100% 325M/325M [00:04<00:00, 82.4MB/s, download_providers=['github', 'huggingface'], file_name=gfpgan_1.4.onnx]
# Downloading: 100% 8.00/8.00 [00:00<00:00, 62.9B/s, download_providers=['github', 'huggingface'], file_name=elon_musk_224.hash]
# Downloading: 100% 685M/685M [00:01<00:00, 549MB/s, download_providers=['github', 'huggingface'], file_name=elon_musk_224.dfm]
# Downloading: 100% 8.00/8.00 [00:00<00:00, 19.8B/s, download_providers=['github', 'huggingface'], file_name=live_portrait_feature_extractor.hash]
# Downloading: 100% 8.00/8.00 [00:00<00:00, 20.0B/s, download_providers=['github', 'huggingface'], file_name=live_portrait_motion_extractor.hash]
# Downloading: 100% 8.00/8.00 [00:00<00:00, 20.1B/s, download_providers=['github', 'huggingface'], file_name=live_portrait_generator.hash]
# Downloading: 100% 3.20M/3.20M [00:00<00:00, 7.77MB/s, download_providers=['github', 'huggingface'], file_name=live_portrait_feature_extractor.onnx]
# Downloading: 100% 107M/107M [00:01<00:00, 59.5MB/s, download_providers=['github', 'huggingface'], file_name=live_portrait_motion_extractor.onnx]
# Downloading: 100% 212M/212M [00:03<00:00, 64.5MB/s, download_providers=['github', 'huggingface'], file_name=live_portrait_generator.onnx]
# Downloading: 100% 8.00/8.00 [00:00<00:00, 53.3B/s, download_providers=['github', 'huggingface'], file_name=simswap_unofficial_512.hash]
# Downloading: 100% 8.00/8.00 [00:00<00:00, 18.1B/s, download_providers=['github', 'huggingface'], file_name=arcface_converter_simswap.hash]
# Downloading: 100% 228M/228M [00:06<00:00, 38.2MB/s, download_providers=['github', 'huggingface'], file_name=simswap_unofficial_512.onnx]
# Downloading: 100% 20.0M/20.0M [00:00<00:00, 32.0MB/s, download_providers=['github', 'huggingface'], file_name=arcface_converter_simswap.onnx]
# Downloading: 100% 8.00/8.00 [00:00<00:00, 53.8B/s, download_providers=['github', 'huggingface'], file_name=uniface_256.hash]
# Downloading: 100% 388M/388M [00:21<00:00, 19.1MB/s, download_providers=['github', 'huggingface'], file_name=uniface_256.onnx]
# Downloading: 100% 8.00/8.00 [00:00<00:00, 20.4B/s, download_providers=['github', 'huggingface'], file_name=simswap_256.hash]
# Downloading: 100% 210M/210M [00:03<00:00, 64.5MB/s, download_providers=['github', 'huggingface'], file_name=simswap_256.onnx]
# Downloading: 100% 8.00/8.00 [00:00<00:00, 19.1B/s, download_providers=['github', 'huggingface'], file_name=inswapper_128.hash]
# Downloading: 100% 530M/530M [00:01<00:00, 322MB/s, download_providers=['github', 'huggingface'], file_name=inswapper_128.onnx]
# Downloading: 100% 8.00/8.00 [00:00<00:00, 19.9B/s, download_providers=['github', 'huggingface'], file_name=hyperswap_1c_256.hash]
# Downloading: 100% 384M/384M [00:05<00:00, 79.1MB/s, download_providers=['github', 'huggingface'], file_name=hyperswap_1c_256.onnx]
# Downloading: 100% 8.00/8.00 [00:00<00:00, 19.1B/s, download_providers=['github', 'huggingface'], file_name=hyperswap_1b_256.hash]
# Downloading: 100% 384M/384M [00:04<00:00, 82.9MB/s, download_providers=['github', 'huggingface'], file_name=hyperswap_1b_256.onnx]
# Downloading: 100% 8.00/8.00 [00:00<00:00, 20.2B/s, download_providers=['github', 'huggingface'], file_name=hyperswap_1a_256.hash]
# Downloading: 100% 384M/384M [00:04<00:00, 83.0MB/s, download_providers=['github', 'huggingface'], file_name=hyperswap_1a_256.onnx]
# Downloading: 100% 8.00/8.00 [00:00<00:00, 18.2B/s, download_providers=['github', 'huggingface'], file_name=hififace_unofficial_256.hash]
# Downloading: 100% 8.00/8.00 [00:00<00:00, 52.2B/s, download_providers=['github', 'huggingface'], file_name=arcface_converter_hififace.hash]
# Downloading: 100% 194M/194M [00:02<00:00, 70.3MB/s, download_providers=['github', 'huggingface'], file_name=hififace_unofficial_256.onnx]
# Downloading: 100% 20.0M/20.0M [00:00<00:00, 34.9MB/s, download_providers=['github', 'huggingface'], file_name=arcface_converter_hififace.onnx]
# Downloading: 100% 8.00/8.00 [00:00<00:00, 19.7B/s, download_providers=['github', 'huggingface'], file_name=blendswap_256.hash]
# Downloading: 100% 1.55G/1.55G [00:05<00:00, 303MB/s, download_providers=['github', 'huggingface'], file_name=blendswap_256.onnx]
# Downloading: 100% 8.00/8.00 [00:00<00:00, 19.6B/s, download_providers=['github', 'huggingface'], file_name=ghost_1_256.hash]
# Downloading: 100% 8.00/8.00 [00:00<00:00, 20.0B/s, download_providers=['github', 'huggingface'], file_name=arcface_converter_ghost.hash]
# Downloading: 100% 491M/491M [00:01<00:00, 279MB/s, download_providers=['github', 'huggingface'], file_name=ghost_1_256.onnx]
# Downloading: 100% 20.0M/20.0M [00:00<00:00, 42.3MB/s, download_providers=['github', 'huggingface'], file_name=arcface_converter_ghost.onnx]
# Downloading: 100% 8.00/8.00 [00:00<00:00, 20.0B/s, download_providers=['github', 'huggingface'], file_name=ghost_2_256.hash]
# Downloading: 100% 705M/705M [00:42<00:00, 17.3MB/s, download_providers=['github', 'huggingface'], file_name=ghost_2_256.onnx]
# [PROGRAM.CORE] Processing step 1 of 1
# Analysing: 100% 430/430 [00:00<00:00, 625.01frame/s, rate=0]
# [PROGRAM.CORE] Extracting frames with a resolution of 1280x720 and 30.0 frames per second
# Extracting: 100% 430/430 [00:05<00:00, 72.47frame/s]
# [PROGRAM.F_S] Processing
# Processing: 100% 430/430 [00:40<00:00, 10.57frame/s, execution_providers=['cuda']]
# [PROGRAM.CORE] Merging video with a resolution of 1280x720 and 30.0 frames per second
# Merging: 100% 430/430 [00:03<00:00, 109.87frame/s]
# [PROGRAM.CORE] Processing to video succeed in 51.89 seconds
# [PROGRAM.CORE] Processing step 1 of 1
# [PROGRAM.CORE] Extracting frames with a resolution of 1280x720 and 30.0 frames per second
# Extracting: 100% 430/430 [00:05<00:00, 76.54frame/s]
# [PROGRAM.F_S] Processing
# Processing: 100% 430/430 [00:38<00:00, 11.14frame/s, execution_providers=['cuda']]
# [PROGRAM.CORE] Merging video with a resolution of 1280x720 and 30.0 frames per second
# Merging: 100% 430/430 [00:04<00:00, 106.70frame/s]
# [PROGRAM.CORE] Processing to video succeed in 48.82 seconds
# [PROGRAM.CORE] Processing step 1 of 1
# [PROGRAM.CORE] Extracting frames with a resolution of 1280x720 and 30.0 frames per second
# Extracting: 100% 430/430 [00:05<00:00, 76.77frame/s]
# [PROGRAM.F_S] Processing
# Processing: 100% 430/430 [00:37<00:00, 11.34frame/s, execution_providers=['cuda']]
# [PROGRAM.CORE] Merging video with a resolution of 1280x720 and 30.0 frames per second
# Merging: 100% 430/430 [00:03<00:00, 110.28frame/s]
# [PROGRAM.CORE] Processing to video succeed in 48.02 seconds
# [PROGRAM.CORE] Processing step 1 of 1
# [PROGRAM.CORE] Extracting frames with a resolution of 1280x720 and 30.0 frames per second
# Extracting: 100% 430/430 [00:05<00:00, 77.01frame/s]
# [PROGRAM.F_S] Processing
# Processing: 100% 430/430 [00:49<00:00,  8.65frame/s, execution_providers=['cuda']]
# [PROGRAM.CORE] Merging video with a resolution of 1280x720 and 30.0 frames per second
# Merging: 100% 430/430 [00:04<00:00, 105.78frame/s]
# [PROGRAM.CORE] Processing to video succeed in 60.12 seconds
# [PROGRAM.CORE] Processing step 1 of 1
# Analysing: 100% 18955/18955 [00:26<00:00, 712.02frame/s, rate=0]
# [PROGRAM.CORE] Extracting frames with a resolution of 1280x720 and 30.0 frames per second
# Extracting: 100% 18955/18955 [03:02<00:00, 104.09frame/s]
# [PROGRAM.F_S] Processing
# Processing: 100% 18955/18955 [27:24<00:00, 11.52frame/s, execution_providers=['cuda']]
# [PROGRAM.CORE] Merging video with a resolution of 1280x720 and 30.0 frames per second
# Merging: 100% 18955/18955 [02:44<00:00, 115.00frame/s]
# [PROGRAM.CORE] Processing to video succeed in 2032.80 seconds
# [PROGRAM.CORE] Processing step 1 of 1
# Analysing: 100% 586/586 [00:01<00:00, 539.35frame/s, rate=0]
# [PROGRAM.CORE] Extracting frames with a resolution of 1280x720 and 25.0 frames per second
# Extracting: 100% 586/586 [00:14<00:00, 40.20frame/s]
# [PROGRAM.F_S] Processing
# Processing: 100% 586/586 [01:11<00:00,  8.24frame/s, execution_providers=['cuda']]
# [PROGRAM.CORE] Merging video with a resolution of 1280x720 and 25.0 frames per second
# Merging: 100% 586/586 [00:05<00:00, 107.63frame/s]
# [PROGRAM.CORE] Processing to video succeed in 93.62 seconds
# [PROGRAM.CORE] Processing step 1 of 1
# [PROGRAM.CORE] Extracting frames with a resolution of 1280x720 and 25.0 frames per second
# Extracting: 100% 586/586 [00:14<00:00, 40.00frame/s]
# [PROGRAM.F_S] Processing
# Processing: 100% 586/586 [00:49<00:00, 11.83frame/s, execution_providers=['cuda']]
# [PROGRAM.CORE] Merging video with a resolution of 1280x720 and 25.0 frames per second
# Merging: 100% 586/586 [00:05<00:00, 106.57frame/s]
# [PROGRAM.CORE] Processing to video succeed in 70.59 seconds
# [PROGRAM.CORE] Processing step 1 of 1
# [PROGRAM.CORE] Extracting frames with a resolution of 1280x720 and 25.0 frames per second
# Extracting: 100% 586/586 [00:14<00:00, 39.39frame/s]
# [PROGRAM.F_S] Processing
# Processing: 100% 586/586 [00:36<00:00, 15.92frame/s, execution_providers=['cuda']]
# [PROGRAM.CORE] Merging video with a resolution of 1280x720 and 25.0 frames per second
# Merging: 100% 586/586 [00:05<00:00, 109.12frame/s]
# [PROGRAM.CORE] Processing to video succeed in 57.93 seconds
# [PROGRAM.CORE] Processing step 1 of 1
# Analysing: 100% 1010/1010 [00:01<00:00, 662.92frame/s, rate=0]
# [PROGRAM.CORE] Extracting frames with a resolution of 1280x720 and 25.0 frames per second
# Extracting: 100% 1010/1010 [00:11<00:00, 87.23frame/s]
# [PROGRAM.F_S] Processing
# Processing: 100% 1010/1010 [02:03<00:00,  8.16frame/s, execution_providers=['cuda']]
# [PROGRAM.CORE] Merging video with a resolution of 1280x720 and 25.0 frames per second
# Merging: 100% 1010/1010 [00:09<00:00, 110.51frame/s]
# [PROGRAM.CORE] Processing to video succeed in 147.87 seconds
# [PROGRAM.CORE] Processing step 1 of 1
# [PROGRAM.CORE] Extracting frames with a resolution of 1280x720 and 25.0 frames per second
# Extracting: 100% 1010/1010 [00:11<00:00, 87.02frame/s]
# [PROGRAM.F_S] Processing
# Processing: 100% 1010/1010 [01:00<00:00, 16.58frame/s, execution_providers=['cuda']]
# [PROGRAM.CORE] Merging video with a resolution of 1280x720 and 25.0 frames per second
# Merging: 100% 1010/1010 [00:09<00:00, 111.41frame/s]
# [PROGRAM.CORE] Processing to video succeed in 82.82 seconds
# [PROGRAM.CORE] Processing step 1 of 1
# Analysing: 100% 12110/12110 [00:20<00:00, 605.23frame/s, rate=0]
# [PROGRAM.CORE] Extracting frames with a resolution of 1280x720 and 25.0 frames per second
# Extracting: 100% 12110/12110 [02:18<00:00, 87.74frame/s]
# [PROGRAM.F_S] Processing
# Processing: 100% 12110/12110 [21:43<00:00,  9.29frame/s, execution_providers=['cuda']]
# [PROGRAM.CORE] Merging video with a resolution of 1280x720 and 25.0 frames per second
# Merging: 100% 12110/12110 [01:48<00:00, 111.92frame/s]
# [PROGRAM.CORE] Processing to video succeed in 1580.65 seconds
# [PROGRAM.CORE] Processing step 1 of 1
# [PROGRAM.CORE] Extracting frames with a resolution of 1280x720 and 25.0 frames per second
# Extracting: 100% 12110/12110 [02:16<00:00, 88.45frame/s]
# [PROGRAM.F_S] Processing
# Processing: 100% 12110/12110 [23:24<00:00,  8.62frame/s, execution_providers=['cuda']]
# [PROGRAM.CORE] Merging video with a resolution of 1280x720 and 25.0 frames per second
# Merging: 100% 12110/12110 [01:47<00:00, 112.19frame/s]
# [PROGRAM.CORE] Processing to video succeed in 1660.96 seconds
# [PROGRAM.CORE] Processing step 1 of 1
# Analysing: 100% 15491/15491 [00:22<00:00, 691.40frame/s, rate=0]
# [PROGRAM.CORE] Extracting frames with a resolution of 1280x720 and 25.0 frames per second
# Extracting: 100% 15491/15491 [02:38<00:00, 97.85frame/s]
# [PROGRAM.F_S] Processing
# Processing: 100% 15491/15491 [29:00<00:00,  8.90frame/s, execution_providers=['cuda']]
# [PROGRAM.CORE] Merging video with a resolution of 1280x720 and 25.0 frames per second
# Merging: 100% 15491/15491 [02:12<00:00, 116.78frame/s]
# [PROGRAM.CORE] Processing to video succeed in 2065.71 seconds
# [PROGRAM.CORE] Processing step 1 of 1
# Analysing: 100% 15491/15491 [01:43<00:00, 150.10frame/s, rate=0]
# [PROGRAM.CORE] Extracting frames with a resolution of 1280x720 and 25.0 frames per second
# Extracting: 100% 15491/15491 [02:54<00:00, 88.88frame/s]
# [PROGRAM.F_S] Processing
# Processing: 100% 15491/15491 [30:47<00:00,  8.38frame/s, execution_providers=['cuda']]
# [PROGRAM.CORE] Merging video with a resolution of 1280x720 and 25.0 frames per second
# Merging: 100% 15491/15491 [02:12<00:00, 117.12frame/s]
# [PROGRAM.CORE] Processing to video succeed in 2269.93 seconds
